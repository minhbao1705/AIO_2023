# %% [markdown]
# ### Series in Pandas

# %% [markdown]
# Drop a row

# %%
import pandas as pd

data = pd.Series(['C++', 'Golang', 'Java', 'Python', 'Swift'],
                 index=list('CGJPS'),
                 name='Programming Language')

# %%
print(data)
# Out:
# C       C++
# G    Golang
# J      Java
# P    Python
# S     Swift
# Name: Programming Language, dtype: object

# %%
data.drop(['C', 'P'])
# Out:
# G    Golang
# J      Java
# S     Swift
# Name: Programming Language, dtype: object

# %%
data
# Out:
# C       C++
# G    Golang
# J      Java
# P    Python
# S     Swift
# Name: Programming Language, dtype: object

# %% [markdown]
# Insert a row

# %%
data['K'] = 'Kotlin'

# %%
data
# Out:
# C       C++
# G    Golang
# J      Java
# P    Python
# S     Swift
# K    Kotlin
# Name: Programming Language, dtype: object

# %%
data.sort_index(inplace=True)
data
# Out:
# C       C++
# G    Golang
# J      Java
# K    Kotlin
# P    Python
# S     Swift
# Name: Programming Language, dtype: object

# %%
import pandas as pd

data = pd.Series([5, 7, 5, 1, 6],
                 name='num_dropped')
data[2.5] = 9
data.sort_index(inplace=True)
data
# Out:
# 0.0    5
# 1.0    7
# 2.0    5
# 2.5    9
# 3.0    1
# 4.0    6
# Name: num_dropped, dtype: int64

# %%
data.reset_index(drop=True)
# Out:
# 0    5
# 1    7
# 2    5
# 3    9
# 4    1
# 5    6
# Name: num_dropped, dtype: int64

# %% [markdown]
# Common pandas in functions

# %%
import pandas as pd

data = pd.Series([5, 7, 5, 1, 6],
                 name='num_dropped')

# %%
data.min()
# Out:
# 1

# %%
data.max()
# Out:
# 7

# %%
data.sum()
# Out:
# 24

# %%
data.mean()
# Out:
# 4.8

# %%
data.std()
# Out:
# 2.280350850198276

# %%
data.var()
# Out:
# 5.2

# %%
data.idxmax()
# Out:
# 1

# %%
data.argmax()
# Out:
# 1

# %%
import pandas as pd

data = pd.Series(['C++', 'Golang', 'Java', 'Python', 'Swift'],
                 index=list('CGJPS'),
                 name='Programming Language')

# %%
data.str.count('Java')
# Out:
# C    0
# G    0
# J    1
# P    0
# S    0
# Name: Programming Language, dtype: int64

# %%
data.str.count('a')
# Out:
# C    0
# G    1
# J    2
# P    0
# S    0
# Name: Programming Language, dtype: int64

# %%
data.str.upper()
# Out:
# C       C++
# G    GOLANG
# J      JAVA
# P    PYTHON
# S     SWIFT
# Name: Programming Language, dtype: object

# %%
data.replace('Java', 'C#')
# Out:
# C       C++
# G    Golang
# J        C#
# P    Python
# S     Swift
# Name: Programming Language, dtype: object

# %%
import pandas as pd
import numpy as np

data = pd.Series([1, 6, 3, 8, np.nan, 7, np.nan, 2],
                 name='num_dropped')
data
# Out:
# 0    1.0
# 1    6.0
# 2    3.0
# 3    8.0
# 4    NaN
# 5    7.0
# 6    NaN
# 7    2.0
# Name: num_dropped, dtype: float64

# %%
data.dropna()
# Out:
# 0    1.0
# 1    6.0
# 2    3.0
# 3    8.0
# 5    7.0
# 7    2.0
# Name: num_dropped, dtype: float64

# %%
data.fillna(1.0)
# Out:
# 0    1.0
# 1    6.0
# 2    3.0
# 3    8.0
# 4    1.0
# 5    7.0
# 6    1.0
# 7    2.0
# Name: num_dropped, dtype: float64

# %%
data.interpolate()
# Out:
# 0    1.0
# 1    6.0
# 2    3.0
# 3    8.0
# 4    7.5
# 5    7.0
# 6    4.5
# 7    2.0
# Name: num_dropped, dtype: float64

# %% [markdown]
# Addition between two series

# %%
import pandas as pd

center1 = pd.Series([12, 23, 3, 11, 9],
                    index=list(['C++', 'Golang',
                                'Java', 'Python',
                                'Swift']),
                    name='num_registerd')

center2 = pd.Series([42, 18, 44, 49, 27],
                    index=list(['C++', 'Golang',
                                'Java', 'Python',
                                'Swift']),
                    name='num_registerd')

total = center1 + center2

# %%
total
# Out:
# C++       54
# Golang    41
# Java      47
# Python    60
# Swift     36
# Name: num_registerd, dtype: int64

# %%
import pandas as pd

center1 = pd.Series([12, 23, 3, 11, 9],
                    index=list(['C++', 'Golang',
                                'Java', 'Python',
                                'Swift']),
                    name='num_registerd')

center2 = pd.Series([18, 44, 49, 27],
                    index=list(['Golang',
                                'Java', 'Python',
                                'Swift']),
                    name='num_registerd')

total = center1 + center2
print(total)
# Out:
# C++        NaN
# Golang    41.0
# Java      47.0
# Python    60.0
# Swift     36.0
# Name: num_registerd, dtype: float64

# %% [markdown]
# Group values

# %%
import pandas as pd

data = pd.Series([4, 1, 0, 2, 2, 1],
                    index=list(['C++', 'Golang',
                                'Java', 'Golang',
                                'Java', 'C++']),
                    name='num_dropped')
print(data)
# Out:
# C++       4
# Golang    1
# Java      0
# Golang    2
# Java      2
# C++       1
# Name: num_dropped, dtype: int64

# %%
data.groupby(level=0).sum()
# Out:
# C++       5
# Golang    3
# Java      2
# Name: num_dropped, dtype: int64

# %%
data.groupby(data>3).sum()
# Out:
# num_dropped
# False    6
# True     4
# Name: num_dropped, dtype: int64

# %%
data['C++'].sum()
# Out:
# 5

# %%
data['Golang'].sum()
# Out:
# 3

# %%
data['Java'].sum()
# Out:
# 2

# %% [markdown]
# ### Data Frame

# %% [markdown]
# Sorting

# %%
import pandas as pd

df = pd.read_csv('advertising_simple.csv')
df.sort_values('Sales')
# Out:
#     TV  Radio  Newspaper  Sales
# 7    8      2          1      4
# 4    8     48         75      7
# 0   44     39         45     10
# 5   57     32         23     11
# 1   17     45         69     12
# 6  120     19         11     13
# 2  151     41         58     16
# 3  180     10         58     17

# %%
import pandas as pd

df = pd.read_csv('advertising_simple.csv')
df.sort_values(['Newspaper','Sales'])
# Out:
#     TV  Radio  Newspaper  Sales
# 7    8      2          1      4
# 6  120     19         11     13
# 5   57     32         23     11
# 0   44     39         45     10
# 2  151     41         58     16
# 3  180     10         58     17
# 1   17     45         69     12
# 4    8     48         75      7

# %%
import pandas as pd

df = pd.read_csv('advertising_simple.csv')
df['ID'] = list(range(2, 10))
df = df.set_index('ID')

# %%
df
# Out:
#      TV  Radio  Newspaper  Sales
# ID
# 2    44     39         45     10
# 3    17     45         69     12
# 4   151     41         58     16
# 5   180     10         58     17
# 6     8     48         75      7
# 7    57     32         23     11
# 8   120     19         11     13
# 9     8      2          1      4

# %%
df.drop('TV', axis=1)
# Out:
#     Radio  Newspaper  Sales
# ID
# 2      39         45     10
# 3      45         69     12
# 4      41         58     16
# 5      10         58     17
# 6      48         75      7
# 7      32         23     11
# 8      19         11     13
# 9       2          1      4

# %% [markdown]
# Group by

# %%
import pandas as pd

df = pd.read_csv('weatherHistory_simple.csv')
df.describe()
# Out:
#        Temperature (C)
# count        10.000000
# mean          6.250000
# std           7.638099
# min          -2.100000
# 25%          -0.925000
# 50%           6.350000
# 75%          13.525000
# max          14.700000

# %%
df.groupby('Precip Type').mean('Temperature (C)')
df['Fahrenheit'] = df['Temperature (C)']*9/5.0 + 32

# %%
df
# Out:
#   Precip Type  Temperature (C)  Fahrenheit
# 0        rain             12.2       53.96
# 1        rain             13.8       56.84
# 2        rain             14.7       58.46
# 3        rain             13.8       56.84
# 4        rain             12.7       54.86
# 5        rain              0.5       32.90
# 6        snow             -0.4       31.28
# 7        snow             -1.1       30.02
# 8        snow             -1.6       29.12
# 9        snow             -2.1       28.22

# %% [markdown]
# loc and iloc

# %%
import pandas as pd

df = pd.read_csv('advertising_simple.csv')
df.set_index([['A', 'B', 'C', 'D',
               'F', 'G', 'H', 'I']],
               inplace=True)
print(df)
# Out:
#     TV  Radio  Newspaper  Sales
# A   44     39         45     10
# B   17     45         69     12
# C  151     41         58     16
# D  180     10         58     17
# F    8     48         75      7
# G   57     32         23     11
# H  120     19         11     13
# I    8      2          1      4

# %%
df.loc['C', 'Radio']
# Out:
# 41

# %%
df.iloc[2, 1]
# Out:
# 41

# %%
df.loc['B', :]
# Out:
# TV           17
# Radio        45
# Newspaper    69
# Sales        12
# Name: B, dtype: int64

# %%
df.loc['F':'H', 'Radio':'Sales']
# Out:
#    Radio  Newspaper  Sales
# F     48         75      7
# G     32         23     11
# H     19         11     13

# %%
df.loc[['F', 'H'], :]
# Out:
#     TV  Radio  Newspaper  Sales
# F    8     48         75      7
# H  120     19         11     13

# %% [markdown]
# Select values

# %%
import pandas as pd

df = pd.read_csv('advertising_simple.csv')

# %%
# Select * from df where df.Newspaper<30
df.loc[df.Newspaper<30]
# Out:
#     TV  Radio  Newspaper  Sales
# 5   57     32         23     11
# 6  120     19         11     13
# 7    8      2          1      4

# %%
# Select * from df where df.Sales>10
df.loc[df.Sales>10]
# Out:
#     TV  Radio  Newspaper  Sales
# 1   17     45         69     12
# 2  151     41         58     16
# 3  180     10         58     17
# 5   57     32         23     11
# 6  120     19         11     13

# %%
# Select * from df where Sales>10 and Newspaper<30
df.loc[(df.Sales>10)&(df.Newspaper<30)]
# Out:
#     TV  Radio  Newspaper  Sales
# 5   57     32         23     11
# 6  120     19         11     13

# %% [markdown]
# Visualiza data

# %%
import pandas as pd

data = {'Actual Value':     [1, 0, 0, 1, 0, 1, 0, 0, 1],
        'Predicted Value':  [0, 1, 0, 1, 0, 1, 1, 0, 1]}
df = pd.DataFrame(data)
print(df)
# Out:
#    Actual Value  Predicted Value
# 0             1                0
# 1             0                1
# 2             0                0
# 3             1                1
# 4             0                0
# 5             1                1
# 6             0                1
# 7             0                0
# 8             1                1

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt 

confusion_matrix = pd.crosstab(df['Predicted Value'],
                               df['Actual Value'],
                               rownames=['Predicted'],
                               colnames=['Actual'])

sn.heatmap(confusion_matrix, annot=True)
plt.show()

# %% [markdown]
# Convert categories to numbers

# %%
import pandas as pd

df = pd.read_csv('weatherHistory_simple.csv')
print(df)
df['Precip Type'] = pd.Categorical(df['Precip Type']).codes
# Out:
#   Precip Type  Temperature (C)
# 0        rain             12.2
# 1        rain             13.8
# 2        rain             14.7
# 3        rain             13.8
# 4        rain             12.7
# 5        rain              0.5
# 6        snow             -0.4
# 7        snow             -1.1
# 8        snow             -1.6
# 9        snow             -2.1

# %%
df
# Out:
#    Precip Type  Temperature (C)
# 0            0             12.2
# 1            0             13.8
# 2            0             14.7
# 3            0             13.8
# 4            0             12.7
# 5            0              0.5
# 6            1             -0.4
# 7            1             -1.1
# 8            1             -1.6
# 9            1             -2.1

# %% [markdown]
# Case study 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('iris.csv')

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data['species'].value_counts()
# Out:
# species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
sns.jointplot(x="sepal_length", y="sepal_width",
              data=data, hue="species")

# %%
sns.jointplot(x="petal_length", y="petal_width",
              data=data, hue="species")
plt.show()

# %%
sns.stripplot(y='sepal_length', x='species',
              data=data, hue='species')
plt.show()

# %%
sns.stripplot(y='petal_length', x='species',
              data=data, hue='species')
plt.show()

# %%
sns.boxplot(y='sepal_length', x='species',
              data=data, hue='species')
plt.show()

# %%
sns.pairplot(data=data,
             hue='species')

plt.show()

# %%
sns.heatmap(data.iloc[:,0:4].corr(),
            annot=True, fmt="f")
plt.show()

# %% [markdown]
# Case study 2

# %%
import pandas as pd 

df = pd.read_csv('weatherHistory_univariate.csv')
df = df.sort_values('Formatted Date')

df['Formatted Date'] = [pd.to_datetime(x) for x in df['Formatted Date']]

# %%
print(df)
# Out:
#                   Formatted Date  Temperature (C)
# 2880   2006-01-01 00:00:00+01:00         0.577778
# 2881   2006-01-01 01:00:00+01:00         1.161111
# 2882   2006-01-01 02:00:00+01:00         1.666667
# 2883   2006-01-01 03:00:00+01:00         1.711111
# 2884   2006-01-01 04:00:00+01:00         1.183333
# ...                          ...              ...
# 89728  2016-12-31 19:00:00+01:00         0.488889
# 89729  2016-12-31 20:00:00+01:00         0.072222
# 89730  2016-12-31 21:00:00+01:00        -0.233333
# 89731  2016-12-31 22:00:00+01:00        -0.472222
# 89732  2016-12-31 23:00:00+01:00        -0.677778
#
# [96453 rows x 2 columns]

# %%
time1 = pd.Timestamp('2006-01-01 00:00:00+01:00',
                     tz='Europe/Berlin')
time2 = pd.Timestamp('2006-01-31 23:59:59+01:00',
                     tz='Europe/Berlin')

df_jan = df.loc[(df['Formatted Date']<=time2) &
                (df['Formatted Date']>=time1)]
df_jan.plot(x='Formatted Date', y='Temperature (C)',
            kind='line', figsize=(8, 4), title='Temperature (C)')
# Out:
# c:\Users\vomin\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# <Axes: title={'center': 'Temperature (C)'}, xlabel='Formatted Date'>

# %%
df['date'] = [x.date() for x in df['Formatted Date']]
df['month'] = [x.month for x in df['Formatted Date']]
df['year'] = [x.year for x in df['Formatted Date']]
df['day'] = [x.day for x in df['Formatted Date']]
df['hour'] = [x.hour for x in df['Formatted Date']]

# %%
df
# Out:
#                   Formatted Date  Temperature (C)        date  month  year  \
# 2880   2006-01-01 00:00:00+01:00         0.577778  2006-01-01      1  2006
# 2881   2006-01-01 01:00:00+01:00         1.161111  2006-01-01      1  2006
# 2882   2006-01-01 02:00:00+01:00         1.666667  2006-01-01      1  2006
# 2883   2006-01-01 03:00:00+01:00         1.711111  2006-01-01      1  2006
# 2884   2006-01-01 04:00:00+01:00         1.183333  2006-01-01      1  2006
# ...                          ...              ...         ...    ...   ...
# 89728  2016-12-31 19:00:00+01:00         0.488889  2016-12-31     12  2016
# 89729  2016-12-31 20:00:00+01:00         0.072222  2016-12-31     12  2016
# 89730  2016-12-31 21:00:00+01:00        -0.233333  2016-12-31     12  2016
# 89731  2016-12-31 22:00:00+01:00        -0.472222  2016-12-31     12  2016
# 89732  2016-12-31 23:00:00+01:00        -0.677778  2016-12-31     12  2016
#
#        day  hour
# 2880     1     0
# 2881     1     1
# ...

# %%
import numpy as np

df['day_cos'] = [np.cos(x * (2 * np.pi / 24)) for x in df['hour']]
df['day_sin'] = [np.sin(x * (2 * np.pi / 24)) for x in df['hour']]
year = (365.25) * 24 * 60 * 60 
df['timestamp'] = [x.timestamp() for x in df['Formatted Date']]
df['year_cos'] = [np.cos((x) * (2 * np.pi / year)) for x in df['timestamp']]
df['year_sin'] = [np.sin((x) * (2 * np.pi / year)) for x in df['timestamp']]

# %%
df
# Out:
#                   Formatted Date  Temperature (C)        date  month  year  \
# 2880   2006-01-01 00:00:00+01:00         0.577778  2006-01-01      1  2006
# 2881   2006-01-01 01:00:00+01:00         1.161111  2006-01-01      1  2006
# 2882   2006-01-01 02:00:00+01:00         1.666667  2006-01-01      1  2006
# 2883   2006-01-01 03:00:00+01:00         1.711111  2006-01-01      1  2006
# 2884   2006-01-01 04:00:00+01:00         1.183333  2006-01-01      1  2006
# ...                          ...              ...         ...    ...   ...
# 89728  2016-12-31 19:00:00+01:00         0.488889  2016-12-31     12  2016
# 89729  2016-12-31 20:00:00+01:00         0.072222  2016-12-31     12  2016
# 89730  2016-12-31 21:00:00+01:00        -0.233333  2016-12-31     12  2016
# 89731  2016-12-31 22:00:00+01:00        -0.472222  2016-12-31     12  2016
# 89732  2016-12-31 23:00:00+01:00        -0.677778  2016-12-31     12  2016
#
# ...
