# %%
# plot data
import matplotlib.pyplot as plt 

areas = [6.7, 4.6, 3.5, 5.5]
prices = [9.1, 5.9, 4.6, 6.7]
N = len(areas)

plt.scatter(areas, prices)
plt.xlabel('Area (x 100$m^2$)')
plt.ylabel('Price (Tael)')
plt.xlim(3,7)
plt.ylim(4,10)
plt.show()

# %% [markdown]
# #### Implementation

# %%
# shuffle data
def shuffle_data(X, y):
    zip_data = list(zip(X, y))
    random.shuffle(zip_data)
    X_shuffled, y_shuffled = zip(*zip_data)

    return X_shuffled, y_shuffled

# forward
def predict(x, w, b):
    return x*w + b

# compute gradient
def gradient(y_hat, y, x):
    dw = 2*x*(y_hat-y)
    db = 2*(y_hat-y)

    return (dw, db)

# update weights
def update_weight(w, b, lr, dw, db):
    w_new = w - lr*dw
    b_new = b - lr*db

    return(w_new, b_new)

# %%
# data preparation
import numpy as np
import matplotlib.pyplot as plt 

x_data = [6.7, 4.6, 3.5, 5.5]
y_data = [9.1, 5.9, 4.6, 6.7]
N = len(x_data)

print(f'areas: {x_data}')
print(f'prices: {y_data}')
print(f'data_size: {N}')
# Out:
# areas: [6.7, 4.6, 3.5, 5.5]
# prices: [9.1, 5.9, 4.6, 6.7]
# data_size: 4

# %%
import random
# init weights
b = 0.04
w = -0.34
lr = 0.005

# parameter
epoch_max = 30
losses = [] # monitoring

for epoch in range(epoch_max):
    # shuffle data
    x_data_sh, y_data_sh = shuffle_data(x_data, y_data)

    # for an epoch
    for i in range(N):

        # get a sample
        x = x_data_sh[i]
        y = y_data_sh[i]

        # predict y_hat
        y_hat = predict(x, w, b)

        # compute loss
        loss = (y_hat-y) * (y_hat-y)

        # for debug
        losses.append(loss)
        print(loss)

        # compute gradient
        (dw, db) = gradient(y_hat, y, x)

        # update weights
        (w, b) = update_weight(w, b, lr, dw, db)
# Out:
# 72.76090000000002
# 26.838719972099998
# 41.7435505375963
# 2.4245434452352073
# 2.925664356395272
# 1.667333187657012
# 4.335932554105075
# 0.08276709766562353
# 0.07842261288974214
# 0.04067745430633494
# 0.8426600447158209
# 0.1769131415106132
# 4.0766186025060755e-06
# 0.0012495469516167529
# 0.41812611803419286
# 0.2933382114462174
# 0.13864813900387585
# 0.0009085602927642552
# 0.002754981125156933
# 0.45346718360899446
# 0.014187898716805848
# 0.03219157747127718
# 0.20303241999550387
# 0.39522960737596624
# 0.0030816868884627714
# 0.24536220853110544
# 0.07066154595196818
# 0.290032151432558
# 0.13708550907554462
# 0.4852419042121513
# 0.03593241486034477
# 0.006034761539459532
# 0.20486751945972934
# 0.3938258649136075
# 0.01668535433476511
# 0.037182768187952596
# 0.1870655457294829
# 0.03416278301189229
# 0.06559554156741872
# 0.2817010550591157
# 0.0035727266989406437
# 0.12192253113661221
# 0.005164011230273266
# 0.4833334374905089
# 0.1415148153294306
# 0.09480470758297051
# 0.33542362094922323
# 0.000881403097544462
# 0.0006633054098263905
# 0.28547163847119994
# 0.06144738495523112
# 0.2745555925193839
# 0.003041241449697025
# 2.4475694852405925e-05
# 0.3394804170149116
# 0.32179240210177507
# 0.2808813207512813
# 0.023370780188530667
# 0.049497011520178685
# 0.25112675736229945
# 0.34178090174796566
# 0.018506040045972137
# 0.041675468992954184
# 0.23480301278031923
# 0.3575633354864468
# 0.3130048988024923
# 0.0003200188305230257
# 0.005117977622499182
# 0.0031010162154054416
# 0.33660377659552354
# 0.018391680029370756
# 0.29126054405954055
# 0.30400020222986773
# 0.020497226843902722
# 0.04570721057391869
# 0.24453556645094665
# 0.00015617877643053714
# 0.0014821067893624916
# 0.3572935275368116
# 0.3120594671265085
# 0.14749685750901384
# 0.4627267028982816
# 0.03560639261391327
# 0.0051671329296652255
# 0.018114320061784435
# 0.0015479116901695967
# 0.24814584707624446
# 0.3630144856435705
# 0.0011504765727843535
# 0.00851674407087289
# 0.2864949978771219
# 0.3430171154112718
# 0.2614313822184717
# 0.02277893102279929
# 0.31992417612917823
# 0.005814149768722043
# 1.123937016388349e-05
# 0.13551959812857142
# 0.47896691141022685
# 0.03318957781343762
# 0.18701398080872705
# 0.029637584983973654
# 0.06248814633411388
# 0.28111577965965406
# 5.884276751963011e-07
# 0.0030546833952778425
# 0.12259414240631056
# 0.49877615738537623
# 0.030857144096241056
# 0.19188130625749636
# 0.02846656900406495
# 0.35219921076180727
# 0.008315308699209998
# 0.28293795516551473
# 0.01978229664586418
# 0.31010826079065607
# 8.549911196450049e-05
# 0.14514439082535074
# 0.46164953960547594
# 0.03391148697792352

# %%
# get result
print(w, b)
# Out:
# 1.2525766798504057 0.2814901916596646

# %%
import matplotlib.pyplot as plt 
plt.plot(losses)

# %%
import matplotlib.pyplot as plt
plt.plot(losses[-10:])

# %%
area_real = 6
predicted_price = area_real*w + b
print('predicted_price: ', predicted_price)
# Out:
# predicted_price:  7.796950270762099

# %%
#x_data = range(2, 8)
y_data = [x*w + b for x in x_data]
plt.plot(x_data, y_data, 'r')
plt.scatter(areas, prices)
