# %% [markdown]
# <a href="https://colab.research.google.com/github/minhbao1705/AIO-2023/blob/main/M02W03_3.composite_function_2variables_twosamples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Composite function

# %%
'''
f(x) = ax + b
g(f) = (f-y)^2
(x=-2, y=-1)
(x=5, y=13)
'''
# black box: f(x) = 2x + 3

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib qt

# f function
def blackbox_func(x):
  return 2*x-13

def func1(x):
  return 3*x - 7

def func2(x):
  return -x + 8

# plot f_func
x_list = np.arange(-10, 10, 0.1).tolist()
fx_list = [blackbox_func(x) for x in x_list]
fx1_list = [func1(x) for x in x_list]
fx2_list = [func2(x) for x in x_list]

plt.plot(x_list, fx_list, 'r')
plt.plot(x_list, fx1_list, 'g')
plt.plot(x_list, fx2_list, 'b')
plt.show()

# %% [markdown]
# ### Optimization

# %%
import random

# predict function
def predicted_func(x, a, b):
    return a*x + b

# parameters
num_steps = 100
lr = 0.01

# given data
x1 = -2
y1 = -1

x2 = 5
y2 = 13

# 1. set a, b randomly
a = random.random()*10.0 - 5.0
b = random.random()*10.0 - 5.0
print(a, b)

for i in range(num_steps):
    # 2. compute predicted_y1 and predicted_y2, given x1=1 and x2=2
    predicted_y1 = predicted_func(x1, a, b)
    predicted_y2 = predicted_func(x2, a, b)

    # 3. compute g
    g_value_1 = (predicted_y1 - y1)**2
    g_value_2 = (predicted_y2 - y2)**2

    # print
    if i%10==0:
        print(f'a: {a} and b: {b}')
        print(f'g_value_1: {g_value_1} and g_value_1: {g_value_1}')
        print('-------------')

    # 4. compute partial gradients for a and b
    dg_da = 2*x1*(predicted_y1 - y1) + 2*x2*(predicted_y2 - y2)
    dg_db = 2*(predicted_y1 - y1) + 2*(predicted_y2 - y2)

    # 5. update
    a = a - lr*dg_da
    b = b - lr*dg_db
# Out:
# 2.7182812797869715 -0.2673257265226674
# a: 2.7182812797869715 and b: -0.2673257265226674
# g_value_1: 22.12656500807691 and g_value_1: 22.12656500807691
# -------------
# a: 2.258423815406039 and b: 0.6462956515774048
# g_value_1: 8.240068665488103 and g_value_1: 8.240068665488103
# -------------
# a: 2.18392974277627 and b: 1.3244420069049272
# g_value_1: 4.175554992042565 and g_value_1: 4.175554992042565
# -------------
# a: 2.1309358134018757 and b: 1.8072045633465188
# g_value_1: 2.116056265507288 and g_value_1: 2.116056265507288
# -------------
# a: 2.093210525260995 and b: 2.150873345559842
# g_value_1: 1.072359049252373 and g_value_1: 1.072359049252373
# -------------
# a: 2.066354664883299 and b: 2.3955241166049794
# g_value_1: 0.5434420385041413 and g_value_1: 0.5434420385041413
# -------------
# a: 2.047236527628682 and b: 2.5696859924305433
# g_value_1: 0.2754014613104013 and g_value_1: 0.2754014613104013
# -------------
# a: 2.0336267170716558 and b: 2.6936682666800795
# g_value_1: 0.1395658773485311 and g_value_1: 0.1395658773485311
# -------------
# a: 2.0239381715333917 and b: 2.7819287097605336
# g_value_1: 0.07072814366119552 and g_value_1: 0.07072814366119552
# -------------
# a: 2.0170410942924044 and b: 2.8447595124693112
# g_value_1: 0.035843075691533596 and g_value_1: 0.035843075691533596
# -------------

# %%
import numpy as np
import matplotlib.pyplot as plt

# f function
def blackbox_func(x):
    return 2*x + 3

def func1(x):
    return 2.006*x + 2.9402

# plot f_func
x_list = np.arange(-10, 10, 0.1).tolist()
fx_list = [blackbox_func(x) for x in x_list]
fx1_list = [func1(x) for x in x_list]

plt.plot(x_list, fx_list, 'r')
plt.plot(x_list, fx1_list, 'g')
plt.show()
