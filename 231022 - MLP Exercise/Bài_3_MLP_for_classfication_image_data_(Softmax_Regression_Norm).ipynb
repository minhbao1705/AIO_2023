# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# From (redirected): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP&confirm=t&uuid=edfcd851-0cff-44d4-96fa-fe0d5647ef0b
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 33.4MB/s]

# %%
# !unzip -q "/content/FER-2013.zip"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")

# %%
class SoftMaxRegression(nn.Module):
    def __init__(self, input_dims, num_classes):
        super(SoftMaxRegression, self).__init__()
        self.linear = nn.Linear(input_dims, num_classes)

    def forward(self, x):
        x = nn.Flatten()(x)
        out = self.linear(x)
        return out

model = SoftMaxRegression(input_dims=180*180, num_classes=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.9113,  Train_Acc: 0.2813, Val_Loss: 2.2163,  Val_Acc: 0.2852
# Epoch 2/100, Train_Loss: 1.8014,  Train_Acc: 0.3209, Val_Loss: 1.9429,  Val_Acc: 0.3065
# Epoch 3/100, Train_Loss: 1.8128,  Train_Acc: 0.3242, Val_Loss: 2.0956,  Val_Acc: 0.2480
# Epoch 4/100, Train_Loss: 1.7936,  Train_Acc: 0.3297, Val_Loss: 1.8963,  Val_Acc: 0.2700
# Epoch 5/100, Train_Loss: 1.8052,  Train_Acc: 0.3298, Val_Loss: 1.8804,  Val_Acc: 0.3144
# Epoch 6/100, Train_Loss: 1.7653,  Train_Acc: 0.3422, Val_Loss: 1.8788,  Val_Acc: 0.3103
# Epoch 7/100, Train_Loss: 1.7844,  Train_Acc: 0.3386, Val_Loss: 2.4539,  Val_Acc: 0.2215
# Epoch 8/100, Train_Loss: 1.7379,  Train_Acc: 0.3461, Val_Loss: 1.8644,  Val_Acc: 0.3130
# Epoch 9/100, Train_Loss: 1.7594,  Train_Acc: 0.3429, Val_Loss: 2.6503,  Val_Acc: 0.2565
# Epoch 10/100, Train_Loss: 1.7542,  Train_Acc: 0.3506, Val_Loss: 2.0719,  Val_Acc: 0.2471
# Epoch 11/100, Train_Loss: 1.7409,  Train_Acc: 0.3478, Val_Loss: 2.2285,  Val_Acc: 0.2647
# Epoch 12/100, Train_Loss: 1.7444,  Train_Acc: 0.3514, Val_Loss: 2.3658,  Val_Acc: 0.2907
# Epoch 13/100, Train_Loss: 1.7329,  Train_Acc: 0.3504, Val_Loss: 2.1080,  Val_Acc: 0.3058
# Epoch 14/100, Train_Loss: 1.7184,  Train_Acc: 0.3590, Val_Loss: 2.0135,  Val_Acc: 0.3070
# Epoch 15/100, Train_Loss: 1.7596,  Train_Acc: 0.3490, Val_Loss: 2.3294,  Val_Acc: 0.2749
# Epoch 16/100, Train_Loss: 1.7023,  Train_Acc: 0.3633, Val_Loss: 1.8854,  Val_Acc: 0.2758
# Epoch 17/100, Train_Loss: 1.7190,  Train_Acc: 0.3535, Val_Loss: 1.9380,  Val_Acc: 0.3097
# Epoch 18/100, Train_Loss: 1.7129,  Train_Acc: 0.3604, Val_Loss: 2.4575,  Val_Acc: 0.2665
# Epoch 19/100, Train_Loss: 1.7350,  Train_Acc: 0.3548, Val_Loss: 2.1601,  Val_Acc: 0.2637
# Epoch 20/100, Train_Loss: 1.7292,  Train_Acc: 0.3577, Val_Loss: 2.1216,  Val_Acc: 0.2903
# Epoch 21/100, Train_Loss: 1.7252,  Train_Acc: 0.3614, Val_Loss: 2.0043,  Val_Acc: 0.2836
# Epoch 22/100, Train_Loss: 1.7137,  Train_Acc: 0.3584, Val_Loss: 2.0560,  Val_Acc: 0.2882
# Epoch 23/100, Train_Loss: 1.7144,  Train_Acc: 0.3604, Val_Loss: 1.9334,  Val_Acc: 0.3162
# Epoch 24/100, Train_Loss: 1.7085,  Train_Acc: 0.3647, Val_Loss: 1.9642,  Val_Acc: 0.2679
# Epoch 25/100, Train_Loss: 1.7153,  Train_Acc: 0.3608, Val_Loss: 2.2491,  Val_Acc: 0.2588
# Epoch 26/100, Train_Loss: 1.7182,  Train_Acc: 0.3605, Val_Loss: 1.9867,  Val_Acc: 0.2906
# Epoch 27/100, Train_Loss: 1.7000,  Train_Acc: 0.3640, Val_Loss: 1.9817,  Val_Acc: 0.2956
# Epoch 28/100, Train_Loss: 1.6968,  Train_Acc: 0.3655, Val_Loss: 2.0890,  Val_Acc: 0.2829
# Epoch 29/100, Train_Loss: 1.6883,  Train_Acc: 0.3707, Val_Loss: 2.4860,  Val_Acc: 0.2719
# Epoch 30/100, Train_Loss: 1.7135,  Train_Acc: 0.3681, Val_Loss: 2.1036,  Val_Acc: 0.2816
# Epoch 31/100, Train_Loss: 1.7205,  Train_Acc: 0.3605, Val_Loss: 1.9139,  Val_Acc: 0.3239
# Epoch 32/100, Train_Loss: 1.6815,  Train_Acc: 0.3733, Val_Loss: 1.9354,  Val_Acc: 0.3245
# Epoch 33/100, Train_Loss: 1.6805,  Train_Acc: 0.3723, Val_Loss: 1.9818,  Val_Acc: 0.2836
# Epoch 34/100, Train_Loss: 1.6916,  Train_Acc: 0.3698, Val_Loss: 2.0447,  Val_Acc: 0.2889
# Epoch 35/100, Train_Loss: 1.6930,  Train_Acc: 0.3702, Val_Loss: 2.3895,  Val_Acc: 0.2530
# Epoch 36/100, Train_Loss: 1.7043,  Train_Acc: 0.3688, Val_Loss: 1.8096,  Val_Acc: 0.3189
# Epoch 37/100, Train_Loss: 1.6929,  Train_Acc: 0.3697, Val_Loss: 1.7835,  Val_Acc: 0.3429
# Epoch 38/100, Train_Loss: 1.6754,  Train_Acc: 0.3757, Val_Loss: 2.6057,  Val_Acc: 0.2839
# Epoch 39/100, Train_Loss: 1.6690,  Train_Acc: 0.3770, Val_Loss: 2.0070,  Val_Acc: 0.2862
# Epoch 40/100, Train_Loss: 1.6916,  Train_Acc: 0.3733, Val_Loss: 2.1948,  Val_Acc: 0.2743
# Epoch 41/100, Train_Loss: 1.6959,  Train_Acc: 0.3679, Val_Loss: 1.9874,  Val_Acc: 0.3077
# Epoch 42/100, Train_Loss: 1.6969,  Train_Acc: 0.3724, Val_Loss: 2.0227,  Val_Acc: 0.3064
# Epoch 43/100, Train_Loss: 1.6737,  Train_Acc: 0.3769, Val_Loss: 1.8439,  Val_Acc: 0.3229
# Epoch 44/100, Train_Loss: 1.6814,  Train_Acc: 0.3779, Val_Loss: 1.7669,  Val_Acc: 0.3239
# Epoch 45/100, Train_Loss: 1.6929,  Train_Acc: 0.3726, Val_Loss: 2.0521,  Val_Acc: 0.2990
# Epoch 46/100, Train_Loss: 1.6714,  Train_Acc: 0.3773, Val_Loss: 1.7261,  Val_Acc: 0.3437
# Epoch 47/100, Train_Loss: 1.6743,  Train_Acc: 0.3769, Val_Loss: 2.0557,  Val_Acc: 0.2724
# Epoch 48/100, Train_Loss: 1.6788,  Train_Acc: 0.3736, Val_Loss: 1.8941,  Val_Acc: 0.3306
# Epoch 49/100, Train_Loss: 1.6695,  Train_Acc: 0.3802, Val_Loss: 2.7882,  Val_Acc: 0.2611
# Epoch 50/100, Train_Loss: 1.6996,  Train_Acc: 0.3749, Val_Loss: 2.0415,  Val_Acc: 0.3011
# Epoch 51/100, Train_Loss: 1.6707,  Train_Acc: 0.3766, Val_Loss: 2.0199,  Val_Acc: 0.2690
# Epoch 52/100, Train_Loss: 1.6836,  Train_Acc: 0.3787, Val_Loss: 2.1881,  Val_Acc: 0.2527
# Epoch 53/100, Train_Loss: 1.6463,  Train_Acc: 0.3850, Val_Loss: 1.9695,  Val_Acc: 0.2958
# Epoch 54/100, Train_Loss: 1.6888,  Train_Acc: 0.3750, Val_Loss: 2.0316,  Val_Acc: 0.3146
# Epoch 55/100, Train_Loss: 1.6568,  Train_Acc: 0.3828, Val_Loss: 2.0385,  Val_Acc: 0.2995
# Epoch 56/100, Train_Loss: 1.6559,  Train_Acc: 0.3810, Val_Loss: 1.8055,  Val_Acc: 0.3346
# Epoch 57/100, Train_Loss: 1.6758,  Train_Acc: 0.3797, Val_Loss: 2.1754,  Val_Acc: 0.2901
# Epoch 58/100, Train_Loss: 1.6737,  Train_Acc: 0.3835, Val_Loss: 1.9707,  Val_Acc: 0.3119
# Epoch 59/100, Train_Loss: 1.6603,  Train_Acc: 0.3803, Val_Loss: 2.0556,  Val_Acc: 0.2977
# Epoch 60/100, Train_Loss: 1.6751,  Train_Acc: 0.3811, Val_Loss: 2.2205,  Val_Acc: 0.2902
# Epoch 61/100, Train_Loss: 1.6677,  Train_Acc: 0.3834, Val_Loss: 1.9294,  Val_Acc: 0.2933
# Epoch 62/100, Train_Loss: 1.6546,  Train_Acc: 0.3819, Val_Loss: 2.0167,  Val_Acc: 0.2998
# Epoch 63/100, Train_Loss: 1.6863,  Train_Acc: 0.3796, Val_Loss: 1.9572,  Val_Acc: 0.2823
# Epoch 64/100, Train_Loss: 1.6681,  Train_Acc: 0.3799, Val_Loss: 2.3506,  Val_Acc: 0.2829
# Epoch 65/100, Train_Loss: 1.6699,  Train_Acc: 0.3786, Val_Loss: 2.4115,  Val_Acc: 0.2665
# Epoch 66/100, Train_Loss: 1.6698,  Train_Acc: 0.3841, Val_Loss: 2.3997,  Val_Acc: 0.2864
# Epoch 67/100, Train_Loss: 1.6750,  Train_Acc: 0.3823, Val_Loss: 1.9389,  Val_Acc: 0.2958
# Epoch 68/100, Train_Loss: 1.6727,  Train_Acc: 0.3789, Val_Loss: 1.8702,  Val_Acc: 0.3126
# Epoch 69/100, Train_Loss: 1.6342,  Train_Acc: 0.3870, Val_Loss: 2.0165,  Val_Acc: 0.2953
# Epoch 70/100, Train_Loss: 1.6719,  Train_Acc: 0.3834, Val_Loss: 2.0213,  Val_Acc: 0.3098
# Epoch 71/100, Train_Loss: 1.6889,  Train_Acc: 0.3810, Val_Loss: 2.0596,  Val_Acc: 0.2981
# Epoch 72/100, Train_Loss: 1.6374,  Train_Acc: 0.3877, Val_Loss: 2.0480,  Val_Acc: 0.3045
# Epoch 73/100, Train_Loss: 1.6705,  Train_Acc: 0.3822, Val_Loss: 1.8065,  Val_Acc: 0.3266
# Epoch 74/100, Train_Loss: 1.6439,  Train_Acc: 0.3904, Val_Loss: 1.9985,  Val_Acc: 0.2926
# Epoch 75/100, Train_Loss: 1.6824,  Train_Acc: 0.3788, Val_Loss: 2.0131,  Val_Acc: 0.3019
# Epoch 76/100, Train_Loss: 1.6451,  Train_Acc: 0.3907, Val_Loss: 2.0294,  Val_Acc: 0.3057
# Epoch 77/100, Train_Loss: 1.6587,  Train_Acc: 0.3881, Val_Loss: 2.4330,  Val_Acc: 0.2916
# Epoch 78/100, Train_Loss: 1.6735,  Train_Acc: 0.3825, Val_Loss: 2.3135,  Val_Acc: 0.3047
# Epoch 79/100, Train_Loss: 1.6619,  Train_Acc: 0.3843, Val_Loss: 2.2693,  Val_Acc: 0.2859
# Epoch 80/100, Train_Loss: 1.6385,  Train_Acc: 0.3882, Val_Loss: 2.3481,  Val_Acc: 0.2710
# Epoch 81/100, Train_Loss: 1.6622,  Train_Acc: 0.3825, Val_Loss: 1.8621,  Val_Acc: 0.3274
# Epoch 82/100, Train_Loss: 1.6476,  Train_Acc: 0.3877, Val_Loss: 2.4910,  Val_Acc: 0.2664
# Epoch 83/100, Train_Loss: 1.6443,  Train_Acc: 0.3905, Val_Loss: 2.0928,  Val_Acc: 0.3121
# Epoch 84/100, Train_Loss: 1.6540,  Train_Acc: 0.3856, Val_Loss: 1.8846,  Val_Acc: 0.3001
# Epoch 85/100, Train_Loss: 1.6404,  Train_Acc: 0.3913, Val_Loss: 1.8612,  Val_Acc: 0.3320
# Epoch 86/100, Train_Loss: 1.6429,  Train_Acc: 0.3921, Val_Loss: 2.3648,  Val_Acc: 0.2739
# Epoch 87/100, Train_Loss: 1.6572,  Train_Acc: 0.3883, Val_Loss: 2.1111,  Val_Acc: 0.2941
# Epoch 88/100, Train_Loss: 1.6322,  Train_Acc: 0.3906, Val_Loss: 1.8367,  Val_Acc: 0.3236
# Epoch 89/100, Train_Loss: 1.6616,  Train_Acc: 0.3863, Val_Loss: 1.9678,  Val_Acc: 0.2756
# Epoch 90/100, Train_Loss: 1.6353,  Train_Acc: 0.3940, Val_Loss: 2.4470,  Val_Acc: 0.2446
# Epoch 91/100, Train_Loss: 1.6614,  Train_Acc: 0.3825, Val_Loss: 2.2450,  Val_Acc: 0.2892
# Epoch 92/100, Train_Loss: 1.6409,  Train_Acc: 0.3917, Val_Loss: 1.8632,  Val_Acc: 0.3259
# Epoch 93/100, Train_Loss: 1.6779,  Train_Acc: 0.3819, Val_Loss: 3.1102,  Val_Acc: 0.2634
# Epoch 94/100, Train_Loss: 1.6517,  Train_Acc: 0.3926, Val_Loss: 2.2261,  Val_Acc: 0.2738
# Epoch 95/100, Train_Loss: 1.6812,  Train_Acc: 0.3853, Val_Loss: 2.7547,  Val_Acc: 0.2307
# Epoch 96/100, Train_Loss: 1.6519,  Train_Acc: 0.3860, Val_Loss: 1.9418,  Val_Acc: 0.3149
# Epoch 97/100, Train_Loss: 1.6464,  Train_Acc: 0.3904, Val_Loss: 2.1718,  Val_Acc: 0.2646
# Epoch 98/100, Train_Loss: 1.6458,  Train_Acc: 0.3913, Val_Loss: 2.0857,  Val_Acc: 0.3096
# Epoch 99/100, Train_Loss: 1.6305,  Train_Acc: 0.3955, Val_Loss: 2.1603,  Val_Acc: 0.2715
# Epoch 100/100, Train_Loss: 1.6303,  Train_Acc: 0.3954, Val_Loss: 1.8319,  Val_Acc: 0.3331

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
