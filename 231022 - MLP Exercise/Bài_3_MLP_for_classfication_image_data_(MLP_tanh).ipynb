# %% [markdown]
# ## Download Data

# %%
# !gdown --id 1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP
# From (redirected): https://drive.google.com/uc?id=1bFx6uiQV-GUGwL3PwYRIYdmRCF9hS2bP&confirm=t&uuid=f42523dc-5eb2-48c8-b5f9-52f8d47d5b8e
# To: /content/FER-2013.zip
# 100% 63.3M/63.3M [00:01<00:00, 61.9MB/s]

# %%
# !unzip -q "/content/FER-2013.zip"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
from torch import nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import Resize
from torchvision.io import read_image
import os
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.manual_seed(42)

# %%
batch_size = 256
img_height = 180
img_width = 180
image_count = 28709
train_dir = "/content/train"
val_dir = "/content/test"

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.img_dir = img_dir
        self.classes = os.listdir(img_dir)
        self.image_files = [(os.path.join(cls, img), cls) for cls in self.classes for img in os.listdir(os.path.join(img_dir, cls))]
        self.class_to_idx = {cls: idx for idx, cls in enumerate(self.classes)}
        self.idx_to_class = {idx:cls  for cls, idx in self.class_to_idx.items()}

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path, cls = self.image_files[idx]
        image = self.resize(read_image(os.path.join(self.img_dir, img_path)))
        image = image.type(torch.float32)
        label = self.class_to_idx[cls]
        if self.norm:
            image = (image/127.5) - 1
        return image, label

# %%
train_dataset = ImageDataset(train_dir, True)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(val_dir, True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
image_batch, label_batch = next(iter(train_loader))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  minv = image_batch[i].numpy().min()
  maxv = image_batch[i].numpy().max()
  plt.imshow(np.squeeze(image_batch[i].numpy()), vmin=minv, vmax=maxv, cmap="gray")
  label = label_batch[i]
  plt.title(train_dataset.idx_to_class[label.item()])
  plt.axis("off")

# %%
######################### YOUR CODE HERE #########################
# Thiết kế model theo yêu cầu đề  bài
# Hidden layer 1: Linear layer in_features = input_dims (180*180), out_features = hidden_dims*4 (1024),
# activation = relu
# Hidden layer 2: Linear layer in_features = hidden_dims*4 (1024), out_features = hidden_dims*2 (512),
# activation = relu
# Hidden layer 3: Linear layer in_features = hidden_dims*2 (512), out_features = hidden_dims (256),
# activation = relu
# Output layer: Linear layer in_features = hidden_dims (256), out_features = output_dims (7)

class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
      super(MLP, self).__init__()
      self.linear1 = nn.Linear(input_dims, hidden_dims*4)
      self.linear2 = nn.Linear(hidden_dims*4, hidden_dims*2)
      self.linear3 = nn.Linear(hidden_dims*2, hidden_dims)
      self.out = nn.Linear(hidden_dims, output_dims)
      self.tanh = nn.Tanh()

    def forward(self, x):
      x = nn.Flatten()(x)
      x = self.linear1(x)
      x = self.tanh(x)
      x = self.linear2(x)
      x = self.tanh(x)
      x = self.linear3(x)
      x = self.tanh(x)
      out = self.out(x)
      return out.squeeze(1)
##################################################################

model = MLP(input_dims=180*180, hidden_dims=256, output_dims=7).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.006)

# %%
num_epochs = 100
train_losses = []
train_acc = []
val_losses = []
val_acc = []
for epoch in range(num_epochs):
    model.train()
    train_loss = 0.0
    accuracy = 0
    cnt = 0
    for X, y in train_loader:
        X, y = X.to(device), y.to(device)
        optimizer.zero_grad()
        outputs = model(X)
        loss = criterion(outputs, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        accuracy += (torch.argmax(outputs, 1) == y).sum().item()
        cnt += len(y)
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    accuracy /= cnt
    train_acc.append(accuracy)


    model.eval()
    val_loss = 0.0
    val_accuracy = 0
    cnt = 0
    with torch.no_grad():
        for X, y in val_loader:
            X, y = X.to(device), y.to(device)
            outputs = model(X)
            loss = criterion(outputs, y)
            val_loss += loss.item()
            val_accuracy += (torch.argmax(outputs, 1) == y).sum().item()
            cnt += len(y)
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_accuracy /= cnt
    val_acc.append(val_accuracy)

    print(f"Epoch {epoch+1}/{num_epochs}, Train_Loss: {train_loss:.4f},  Train_Acc: {accuracy:.4f}, Val_Loss: {val_loss:.4f},  Val_Acc: {val_accuracy:.4f}")
# Out:
# Epoch 1/100, Train_Loss: 1.8466,  Train_Acc: 0.2595, Val_Loss: 1.7909,  Val_Acc: 0.2821
# Epoch 2/100, Train_Loss: 1.7761,  Train_Acc: 0.2997, Val_Loss: 1.7402,  Val_Acc: 0.3207
# Epoch 3/100, Train_Loss: 1.7345,  Train_Acc: 0.3270, Val_Loss: 1.7015,  Val_Acc: 0.3405
# Epoch 4/100, Train_Loss: 1.7025,  Train_Acc: 0.3426, Val_Loss: 1.6795,  Val_Acc: 0.3486
# Epoch 5/100, Train_Loss: 1.6839,  Train_Acc: 0.3523, Val_Loss: 1.6612,  Val_Acc: 0.3571
# Epoch 6/100, Train_Loss: 1.6696,  Train_Acc: 0.3588, Val_Loss: 1.6445,  Val_Acc: 0.3642
# Epoch 7/100, Train_Loss: 1.6586,  Train_Acc: 0.3615, Val_Loss: 1.6382,  Val_Acc: 0.3709
# Epoch 8/100, Train_Loss: 1.6510,  Train_Acc: 0.3620, Val_Loss: 1.6341,  Val_Acc: 0.3696
# Epoch 9/100, Train_Loss: 1.6440,  Train_Acc: 0.3679, Val_Loss: 1.6292,  Val_Acc: 0.3689
# Epoch 10/100, Train_Loss: 1.6373,  Train_Acc: 0.3705, Val_Loss: 1.6198,  Val_Acc: 0.3759
# Epoch 11/100, Train_Loss: 1.6324,  Train_Acc: 0.3738, Val_Loss: 1.6186,  Val_Acc: 0.3778
# Epoch 12/100, Train_Loss: 1.6246,  Train_Acc: 0.3759, Val_Loss: 1.6111,  Val_Acc: 0.3761
# Epoch 13/100, Train_Loss: 1.6210,  Train_Acc: 0.3785, Val_Loss: 1.6354,  Val_Acc: 0.3600
# Epoch 14/100, Train_Loss: 1.6133,  Train_Acc: 0.3806, Val_Loss: 1.6090,  Val_Acc: 0.3689
# Epoch 15/100, Train_Loss: 1.6122,  Train_Acc: 0.3809, Val_Loss: 1.6011,  Val_Acc: 0.3760
# Epoch 16/100, Train_Loss: 1.6064,  Train_Acc: 0.3849, Val_Loss: 1.5981,  Val_Acc: 0.3826
# Epoch 17/100, Train_Loss: 1.6026,  Train_Acc: 0.3853, Val_Loss: 1.5978,  Val_Acc: 0.3833
# Epoch 18/100, Train_Loss: 1.5976,  Train_Acc: 0.3867, Val_Loss: 1.5950,  Val_Acc: 0.3856
# Epoch 19/100, Train_Loss: 1.5926,  Train_Acc: 0.3874, Val_Loss: 1.5905,  Val_Acc: 0.3823
# Epoch 20/100, Train_Loss: 1.5906,  Train_Acc: 0.3898, Val_Loss: 1.5923,  Val_Acc: 0.3803
# Epoch 21/100, Train_Loss: 1.5860,  Train_Acc: 0.3909, Val_Loss: 1.5888,  Val_Acc: 0.3806
# Epoch 22/100, Train_Loss: 1.5805,  Train_Acc: 0.3924, Val_Loss: 1.5904,  Val_Acc: 0.3840
# Epoch 23/100, Train_Loss: 1.5798,  Train_Acc: 0.3948, Val_Loss: 1.5844,  Val_Acc: 0.3787
# Epoch 24/100, Train_Loss: 1.5743,  Train_Acc: 0.3950, Val_Loss: 1.5850,  Val_Acc: 0.3809
# Epoch 25/100, Train_Loss: 1.5699,  Train_Acc: 0.3976, Val_Loss: 1.5806,  Val_Acc: 0.3848
# Epoch 26/100, Train_Loss: 1.5684,  Train_Acc: 0.3990, Val_Loss: 1.5863,  Val_Acc: 0.3819
# Epoch 27/100, Train_Loss: 1.5633,  Train_Acc: 0.4012, Val_Loss: 1.5745,  Val_Acc: 0.3881
# Epoch 28/100, Train_Loss: 1.5600,  Train_Acc: 0.4013, Val_Loss: 1.5797,  Val_Acc: 0.3877
# Epoch 29/100, Train_Loss: 1.5570,  Train_Acc: 0.4035, Val_Loss: 1.5709,  Val_Acc: 0.3897
# Epoch 30/100, Train_Loss: 1.5536,  Train_Acc: 0.4081, Val_Loss: 1.5736,  Val_Acc: 0.3941
# Epoch 31/100, Train_Loss: 1.5474,  Train_Acc: 0.4061, Val_Loss: 1.5733,  Val_Acc: 0.3908
# Epoch 32/100, Train_Loss: 1.5452,  Train_Acc: 0.4096, Val_Loss: 1.5799,  Val_Acc: 0.3794
# Epoch 33/100, Train_Loss: 1.5408,  Train_Acc: 0.4111, Val_Loss: 1.5884,  Val_Acc: 0.3761
# Epoch 34/100, Train_Loss: 1.5362,  Train_Acc: 0.4145, Val_Loss: 1.5956,  Val_Acc: 0.3722
# Epoch 35/100, Train_Loss: 1.5324,  Train_Acc: 0.4167, Val_Loss: 1.5752,  Val_Acc: 0.3782
# Epoch 36/100, Train_Loss: 1.5291,  Train_Acc: 0.4167, Val_Loss: 1.5647,  Val_Acc: 0.3801
# Epoch 37/100, Train_Loss: 1.5225,  Train_Acc: 0.4195, Val_Loss: 1.5743,  Val_Acc: 0.3881
# Epoch 38/100, Train_Loss: 1.5191,  Train_Acc: 0.4220, Val_Loss: 1.5853,  Val_Acc: 0.3750
# Epoch 39/100, Train_Loss: 1.5128,  Train_Acc: 0.4246, Val_Loss: 1.6122,  Val_Acc: 0.3704
# Epoch 40/100, Train_Loss: 1.5114,  Train_Acc: 0.4236, Val_Loss: 1.5744,  Val_Acc: 0.3806
# Epoch 41/100, Train_Loss: 1.5037,  Train_Acc: 0.4285, Val_Loss: 1.5804,  Val_Acc: 0.3820
# Epoch 42/100, Train_Loss: 1.4983,  Train_Acc: 0.4312, Val_Loss: 1.5579,  Val_Acc: 0.3883
# Epoch 43/100, Train_Loss: 1.4923,  Train_Acc: 0.4343, Val_Loss: 1.5653,  Val_Acc: 0.3820
# Epoch 44/100, Train_Loss: 1.4871,  Train_Acc: 0.4348, Val_Loss: 1.5517,  Val_Acc: 0.3938
# Epoch 45/100, Train_Loss: 1.4822,  Train_Acc: 0.4399, Val_Loss: 1.5585,  Val_Acc: 0.3912
# Epoch 46/100, Train_Loss: 1.4780,  Train_Acc: 0.4416, Val_Loss: 1.5434,  Val_Acc: 0.3973
# Epoch 47/100, Train_Loss: 1.4720,  Train_Acc: 0.4415, Val_Loss: 1.5462,  Val_Acc: 0.3947
# Epoch 48/100, Train_Loss: 1.4641,  Train_Acc: 0.4478, Val_Loss: 1.5575,  Val_Acc: 0.3884
# Epoch 49/100, Train_Loss: 1.4602,  Train_Acc: 0.4490, Val_Loss: 1.5463,  Val_Acc: 0.3937
# Epoch 50/100, Train_Loss: 1.4509,  Train_Acc: 0.4542, Val_Loss: 1.5495,  Val_Acc: 0.3930
# Epoch 51/100, Train_Loss: 1.4433,  Train_Acc: 0.4560, Val_Loss: 1.5542,  Val_Acc: 0.3963
# Epoch 52/100, Train_Loss: 1.4380,  Train_Acc: 0.4563, Val_Loss: 1.5686,  Val_Acc: 0.3881
# Epoch 53/100, Train_Loss: 1.4303,  Train_Acc: 0.4635, Val_Loss: 1.5661,  Val_Acc: 0.3853
# Epoch 54/100, Train_Loss: 1.4228,  Train_Acc: 0.4671, Val_Loss: 1.5399,  Val_Acc: 0.3952
# Epoch 55/100, Train_Loss: 1.4137,  Train_Acc: 0.4695, Val_Loss: 1.5657,  Val_Acc: 0.3807
# Epoch 56/100, Train_Loss: 1.4083,  Train_Acc: 0.4717, Val_Loss: 1.6236,  Val_Acc: 0.3739
# Epoch 57/100, Train_Loss: 1.3972,  Train_Acc: 0.4780, Val_Loss: 1.5294,  Val_Acc: 0.4028
# Epoch 58/100, Train_Loss: 1.3903,  Train_Acc: 0.4801, Val_Loss: 1.6092,  Val_Acc: 0.3689
# Epoch 59/100, Train_Loss: 1.3801,  Train_Acc: 0.4862, Val_Loss: 1.6239,  Val_Acc: 0.3683
# Epoch 60/100, Train_Loss: 1.3789,  Train_Acc: 0.4843, Val_Loss: 1.6300,  Val_Acc: 0.3731
# Epoch 61/100, Train_Loss: 1.3636,  Train_Acc: 0.4896, Val_Loss: 1.5645,  Val_Acc: 0.3927
# Epoch 62/100, Train_Loss: 1.3511,  Train_Acc: 0.5002, Val_Loss: 1.5632,  Val_Acc: 0.3936
# Epoch 63/100, Train_Loss: 1.3450,  Train_Acc: 0.4993, Val_Loss: 1.5790,  Val_Acc: 0.3852
# Epoch 64/100, Train_Loss: 1.3402,  Train_Acc: 0.5004, Val_Loss: 1.5473,  Val_Acc: 0.3989
# Epoch 65/100, Train_Loss: 1.3270,  Train_Acc: 0.5067, Val_Loss: 1.6526,  Val_Acc: 0.3750
# Epoch 66/100, Train_Loss: 1.3239,  Train_Acc: 0.5103, Val_Loss: 1.5462,  Val_Acc: 0.3957
# Epoch 67/100, Train_Loss: 1.3020,  Train_Acc: 0.5174, Val_Loss: 1.5580,  Val_Acc: 0.4067
# Epoch 68/100, Train_Loss: 1.2984,  Train_Acc: 0.5195, Val_Loss: 1.6441,  Val_Acc: 0.3559
# Epoch 69/100, Train_Loss: 1.2845,  Train_Acc: 0.5253, Val_Loss: 1.8203,  Val_Acc: 0.3316
# Epoch 70/100, Train_Loss: 1.2906,  Train_Acc: 0.5210, Val_Loss: 1.5666,  Val_Acc: 0.3909
# Epoch 71/100, Train_Loss: 1.2602,  Train_Acc: 0.5365, Val_Loss: 1.5697,  Val_Acc: 0.3996
# Epoch 72/100, Train_Loss: 1.2504,  Train_Acc: 0.5408, Val_Loss: 1.5987,  Val_Acc: 0.3962
# Epoch 73/100, Train_Loss: 1.2455,  Train_Acc: 0.5426, Val_Loss: 1.6349,  Val_Acc: 0.3926
# Epoch 74/100, Train_Loss: 1.2389,  Train_Acc: 0.5467, Val_Loss: 1.8116,  Val_Acc: 0.3678
# Epoch 75/100, Train_Loss: 1.2172,  Train_Acc: 0.5574, Val_Loss: 1.6724,  Val_Acc: 0.3607
# Epoch 76/100, Train_Loss: 1.2148,  Train_Acc: 0.5561, Val_Loss: 1.7660,  Val_Acc: 0.3520
# Epoch 77/100, Train_Loss: 1.1923,  Train_Acc: 0.5686, Val_Loss: 1.6575,  Val_Acc: 0.3933
# Epoch 78/100, Train_Loss: 1.1813,  Train_Acc: 0.5690, Val_Loss: 1.6535,  Val_Acc: 0.3930
# Epoch 79/100, Train_Loss: 1.1606,  Train_Acc: 0.5786, Val_Loss: 1.7832,  Val_Acc: 0.3707
# Epoch 80/100, Train_Loss: 1.1689,  Train_Acc: 0.5777, Val_Loss: 1.5796,  Val_Acc: 0.3976
# Epoch 81/100, Train_Loss: 1.1427,  Train_Acc: 0.5878, Val_Loss: 1.7710,  Val_Acc: 0.3787
# Epoch 82/100, Train_Loss: 1.1370,  Train_Acc: 0.5893, Val_Loss: 1.7894,  Val_Acc: 0.3638
# Epoch 83/100, Train_Loss: 1.1156,  Train_Acc: 0.6027, Val_Loss: 1.7832,  Val_Acc: 0.3516
# Epoch 84/100, Train_Loss: 1.1011,  Train_Acc: 0.6057, Val_Loss: 1.5810,  Val_Acc: 0.4078
# Epoch 85/100, Train_Loss: 1.0814,  Train_Acc: 0.6113, Val_Loss: 1.7139,  Val_Acc: 0.3851
# Epoch 86/100, Train_Loss: 1.0821,  Train_Acc: 0.6140, Val_Loss: 1.7499,  Val_Acc: 0.3757
# Epoch 87/100, Train_Loss: 1.0447,  Train_Acc: 0.6291, Val_Loss: 1.7562,  Val_Acc: 0.3853
# Epoch 88/100, Train_Loss: 1.0565,  Train_Acc: 0.6258, Val_Loss: 2.0840,  Val_Acc: 0.3270
# Epoch 89/100, Train_Loss: 1.0394,  Train_Acc: 0.6314, Val_Loss: 2.0182,  Val_Acc: 0.3650
# Epoch 90/100, Train_Loss: 1.0082,  Train_Acc: 0.6469, Val_Loss: 2.1227,  Val_Acc: 0.3516
# Epoch 91/100, Train_Loss: 1.0074,  Train_Acc: 0.6432, Val_Loss: 1.8357,  Val_Acc: 0.3742
# Epoch 92/100, Train_Loss: 0.9976,  Train_Acc: 0.6521, Val_Loss: 1.7209,  Val_Acc: 0.3892
# Epoch 93/100, Train_Loss: 0.9684,  Train_Acc: 0.6613, Val_Loss: 1.7149,  Val_Acc: 0.3982
# Epoch 94/100, Train_Loss: 0.9529,  Train_Acc: 0.6676, Val_Loss: 1.9339,  Val_Acc: 0.3512
# Epoch 95/100, Train_Loss: 0.9397,  Train_Acc: 0.6696, Val_Loss: 1.8578,  Val_Acc: 0.3806
# Epoch 96/100, Train_Loss: 0.9284,  Train_Acc: 0.6776, Val_Loss: 2.0248,  Val_Acc: 0.3553
# Epoch 97/100, Train_Loss: 0.9270,  Train_Acc: 0.6798, Val_Loss: 1.8636,  Val_Acc: 0.3700
# Epoch 98/100, Train_Loss: 0.8838,  Train_Acc: 0.6956, Val_Loss: 2.0387,  Val_Acc: 0.3707
# Epoch 99/100, Train_Loss: 0.8742,  Train_Acc: 0.6996, Val_Loss: 1.9705,  Val_Acc: 0.3593
# Epoch 100/100, Train_Loss: 0.8596,  Train_Acc: 0.7043, Val_Loss: 1.8025,  Val_Acc: 0.4032

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(2, 2, 1)
plt.plot(train_losses, label='loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 2)
plt.plot(train_acc, label='accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('accuracy')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 3)
plt.plot(val_losses, label='val_loss', color='green')
plt.xlabel('Epoch')
plt.ylabel('Error [CrosEntr]')
plt.legend()
plt.grid(True)

plt.subplot(2, 2, 4)
plt.plot(val_acc, label='val_accuracy', color='red')
plt.xlabel('Epoch')
plt.ylabel('val_accuracy')
plt.legend()
plt.grid(True)
